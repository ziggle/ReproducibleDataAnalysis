# %% [markdown]
# https://www.youtube.com/watch?v=_ZEWDGpM-vM&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ

# %%
URL='https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD'

# %%
from urllib.request import urlretrieve
urlretrieve(URL,"Fremont.csv")
# Out:
# ('Fremont.csv', <http.client.HTTPMessage at 0x2373e684d90>)

# %%
import pandas as pd
data=pd.read_csv('Fremont.csv',index_col='Date',parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2022-08-01 00:00:00                  23.0                           7.0
# 2022-08-01 01:00:00                  12.0                           5.0
# 2022-08-01 02:00:00                   3.0                           0.0
# 2022-08-01 03:00:00                   5.0                           2.0
# 2022-08-01 04:00:00                  10.0                           2.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2022-08-01 00:00:00                          16.0
# 2022-08-01 01:00:00                           7.0
# 2022-08-01 02:00:00                           3.0
# 2022-08-01 03:00:00                           3.0
# 2022-08-01 04:00:00                           8.0

# %%
# %matplotlib inline
data.resample('W').sum().plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
data.columns=['West','East','Total']
data.resample('W').sum().plot()
# Out:
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21532\2156350676.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <AxesSubplot: xlabel='Date'>

# %%
ax=data.resample('D').sum().rolling(365).sum().plot()
ax.set_ylim(0,None)
# Out:
# (0.0, 1256022.05)

# %%
data.groupby(data.index.time).mean().plot()
# Out:
# <AxesSubplot: xlabel='time'>

# %%
pivoted=data.pivot_table('Total',index=data.index.time, columns=data.index.date)
pivoted.iloc[:5,:5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00         9.0        11.0         7.0         7.0         5.0
# 01:00:00         6.0         0.0         4.0         5.0         5.0
# 02:00:00         1.0         6.0         3.0         2.0         1.0
# 03:00:00         3.0         3.0         2.0         2.0         2.0
# 04:00:00         1.0         1.0         2.0         1.0         2.0

# %%
pivoted.plot(legend=False,alpha=0.01)
# Out:
# <AxesSubplot: xlabel='time'>
